# %%
import pandas as pd
import re

def procesar_datos(contenido):
    registros = re.split(r'¬-\*-¬DATA', contenido)
    
    datos_procesados = []
    for registro in registros:
        if registro.strip():
            lineas = registro.strip().split('\n')
            datos_registro = {}
            datos_registro['tipo_doc_num'] = None
            datos_registro['marca_sin_informacion'] = 0
            
            for linea in lineas:
                if linea.startswith('5|') or linea.startswith('4|'):
                    partes = linea.split(';')
                    if len(partes) >= 3:
                        tipo_doc = partes[0].split('|')[1]
                        num_doc = partes[1]
                        
                        if 'La consulta no fue exitosa' in linea:
                            nuevo_registro = {'tipo_doc_num': f"{tipo_doc}{num_doc}", 'marca_sin_informacion': 1}
                            datos_procesados.append(nuevo_registro)
                            continue
                        
                        if datos_registro['tipo_doc_num'] is None:
                            datos_registro['tipo_doc_num'] = f"{tipo_doc}{num_doc}"
                        
                        if len(partes) >= 5:
                            seccion = partes[2].strip()
                            campo = partes[3].strip()
                            valor = partes[4].strip()
                            
                        if campo is not None and campo != '':
                            nombre_campo = f"{seccion.lower().replace(' ', '_')}_{campo.lower().replace(' ', '_').replace('|', '_')}"
                            datos_registro[nombre_campo] = valor

            if datos_registro['tipo_doc_num'] is not None:
                datos_procesados.append(datos_registro)
    
    return datos_procesados

def crear_dataframe(datos_procesados):
    df = pd.DataFrame(datos_procesados)
    columnas = ['tipo_doc_num'] + [col for col in df.columns if col != 'tipo_doc_num' and col != 'marca_sin_informacion'] + ['marca_sin_informacion']
    return df[columnas]

# Uso de las funciones
ruta_archivo = 'C:/Users/jpperez/Documents/Prueba_Practica_nlp/Prueba practica/files/RUAF.csv'
with open(ruta_archivo, 'r', encoding='ISO-8859-1') as file:
    contenido = file.read()

datos_procesados = procesar_datos(contenido)
df_final = crear_dataframe(datos_procesados)

# Guardar el resultado en un archivo CSV
df_final.to_csv('C:/Users/jpperez/Documents/Prueba_Practica_nlp/Prueba practica/files/resultado_ruaf.csv', index=False, encoding='utf-8')

print("Proceso completado. El resultado se ha guardado en 'resultado_ruaf.csv'.")
# Out:
# Proceso completado. El resultado se ha guardado en 'resultado_ruaf.csv'.

# %%
df_final
# Out:
#      tipo_doc_num información_basica_segundo_apellido  \
# 0    CC1116912531                                   M
# 1    CC1007273176                               ARIAS
# 2    CC1022385813                                LEON
# 3      CC16616853                               GODOY
# 4    CC1035912005                               URIBE
# ..            ...                                 ...
# 931  CC1062301821                                   F
# 932  CC1056994241                                   M
# 933  CC1112965720                                 NaN
# 934  CC1023035167                                 NaN
# 935  CC1116441348                             CASTAÑO
#
#     información_basica_primer_apellido información_basica_segundo_nombre  \
# 0                               BEDOYA                             MEJIA
# 1                                GOMEZ                            ANDRES
# 2                                OLAYA                             DAVID
# 3                               SOLANO                           GERARDO
# 4                              NARANJO                          CRISTINA
# ..                                 ...                               ...
# 931                              ROJAS                           BURBANO
# 932                          SEPULVEDA                            GALVIS
# 933                                NaN                               NaN
# 934                                NaN                               NaN
# 935                             FRANCO                             PAOLA
#
#     información_basica_primer_nombre  \
# 0                           MAURICIO
# 1                              DAIRO
# 2                           CRISTIAM
# 3                               LUIS
# 4                             ISABEL
# ..                               ...
# 931                          DANIELA
# 932                      HILDEBRANDO
# 933                              NaN
# 934                              NaN
# 935                            JENNY
#
#     información_basica_número_de_identificación  \
# 0                                 CC 1116912531
# 1                                 CC 1007273176
# 2                                 CC 1022385813
# 3                                   CC 16616853
# 4                                 CC 1035912005
# ..                                          ...
# 931                               CC 1062301821
# 932                               CC 1056994241
# 933                                         NaN
# 934                                         NaN
# 935                               CC 1116441348
#
#     afiliación_a_salud_departamento_->_municipio  \
# 0                                      FLORENCIA
# 1                                       MEDELLIN
# 2                                    BOGOTA D.C.
# 3                                    BOGOTA D.C.
# 4                                          BELLO
# ..                                           ...
# 931                       SANTANDER DE QUILICHAO
# 932                                       MADRID
# 933                                          NaN
# 934                                          NaN
# 935                                  BOGOTA D.C.
#
#     afiliación_a_salud_tipo_de_afiliado  \
# 0                             COTIZANTE
# 1                             COTIZANTE
# 2                             COTIZANTE
# 3                          BENEFICIARIO
# 4                             COTIZANTE
# ..                                  ...
# 931                           COTIZANTE
# 932                           COTIZANTE
# 933                                 NaN
# 934                                 NaN
# 935                           COTIZANTE
#
#     afiliación_a_salud_estado_de_afiliación  \
# 0                                    Activo
# 1                                    Activo
# 2                     Activo por emergencia
# 3                                    Activo
# 4                                    Activo
# ..                                      ...
# 931                                  Activo
# 932                                  Activo
# 933                                     NaN
# 934                                     NaN
# 935                                  Activo
#
#     afiliación_a_salud_fecha_afiliacion  ...  \
# 0                            31/12/2020  ...
# 1                            01/09/2018  ...
# 2                            01/10/2015  ...
# 3                            01/10/2017  ...
# 4                            01/04/2010  ...
# ..                                  ...  ...
# 931                          02/05/2013  ...
# 932                          12/01/2007  ...
# 933                                 NaN  ...
# 934                                 NaN  ...
# 935                          01/09/2021  ...
#
#     pensionados_entidad_que_reconoce_la_pensión  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 931      FONDO PENSIONES OBLIGATORIAS COLFONDOS
# 932                                         NaN
# 933                                         NaN
# 934                                         NaN
# 935                                         NaN
#
#     vinculación_a_programas_de__asistencia_social_ubicación_de_entrega_del_beneficio  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
#
#     vinculación_a_programas_de__asistencia_social_fecha_ultimo_beneficio  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
#
#     vinculación_a_programas_de__asistencia_social_estado_del_beneficio  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
#
#     vinculación_a_programas_de__asistencia_social_estado_de_la_vinculación  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
#
#     vinculación_a_programas_de__asistencia_social_fecha_de_vinculación  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
#
#     vinculación_a_programas_de__asistencia_social_programa  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
#
#     vinculación_a_programas_de__asistencia_social_administradora  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 931                                                NaN
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
#
#     afiliación_a_salud_fecha_de_afiliación marca_sin_informacion
# 0                                      NaN                     0
# 1                                      NaN                     0
# 2                                      NaN                     0
# 3                                      NaN                     0
# 4                                      NaN                     0
# ..                                     ...                   ...
# 931                                    NaN                     0
# 932                                    NaN                     0
# 933                                    NaN                     1
# 934                                    NaN                     1
# 935                                    NaN                     0
#
# [936 rows x 48 columns]
